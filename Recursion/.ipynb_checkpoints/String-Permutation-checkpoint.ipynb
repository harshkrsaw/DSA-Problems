# %% [markdown]
# # String Permutation
#
# ## Problem Statement
#
# Given a string, write a function that uses recursion to output a list of all the possible permutations of that string.
#
# For example, given s='abc' the function should return ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']
#
# *Note: If a character is repeated, treat each occurence as distinct, for example an input of 'xxx' would return a list with 6 "versions" of 'xxx'*

# %%
def permute(s):
    out = []

    
    if len(s) == 1:
        out = [s]
        
    else:

        for i, let in enumerate(s):
            
            for perm in permute(s[:i] + s[i+1:]):
                
                out = out + [let + perm]

    return out

# %%
permute('abc')
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']

# %%
permute('harsh')
# Out:
# ['harsh',
#  'harhs',
#  'hasrh',
#  'hashr',
#  'hahrs',
#  'hahsr',
#  'hrash',
#  'hrahs',
#  'hrsah',
#  'hrsha',
#  'hrhas',
#  'hrhsa',
#  'hsarh',
#  'hsahr',
#  'hsrah',
#  'hsrha',
#  'hshar',
#  'hshra',
#  'hhars',
#  'hhasr',
#  'hhras',
#  'hhrsa',
#  'hhsar',
#  'hhsra',
#  'ahrsh',
#  'ahrhs',
#  'ahsrh',
#  'ahshr',
#  'ahhrs',
#  'ahhsr',
#  'arhsh',
#  'arhhs',
#  'arshh',
#  'arshh',
#  'arhhs',
#  'arhsh',
#  'ashrh',
#  'ashhr',
#  'asrhh',
#  'asrhh',
#  'ashhr',
#  'ashrh',
#  'ahhrs',
#  'ahhsr',
#  'ahrhs',
#  'ahrsh',
#  'ahshr',
#  'ahsrh',
#  'rhash',
#  'rhahs',
#  'rhsah',
#  'rhsha',
#  'rhhas',
#  'rhhsa',
#  'rahsh',
#  'rahhs',
#  'rashh',
#  'rashh',
#  'rahhs',
#  'rahsh',
#  'rshah',
#  'rshha',
#  'rsahh',
#  'rsahh',
#  'rshha',
#  'rshah',
#  'rhhas',
#  'rhhsa',
#  'rhahs',
#  'rhash',
#  'rhsha',
#  'rhsah',
#  'sharh',
#  'shahr',
#  'shrah',
#  'shrha',
#  'shhar',
#  'shhra',
#  'sahrh',
#  'sahhr',
#  'sarhh',
#  'sarhh',
#  'sahhr',
#  'sahrh',
#  'srhah',
#  'srhha',
#  'srahh',
#  'srahh',
#  'srhha',
#  'srhah',
#  'shhar',
#  'shhra',
#  'shahr',
#  'sharh',
#  'shrha',
#  'shrah',
#  'hhars',
#  'hhasr',
#  'hhras',
#  'hhrsa',
#  'hhsar',
#  'hhsra',
#  'hahrs',
#  'hahsr',
#  'harhs',
#  'harsh',
#  'hashr',
#  'hasrh',
#  'hrhas',
#  'hrhsa',
#  'hrahs',
#  'hrash',
#  'hrsha',
#  'hrsah',
#  'hshar',
#  'hshra',
#  'hsahr',
#  'hsarh',
#  'hsrha',
#  'hsrah']

# %%
#Revision
#Date: 4/15/26
#secondsolve

# %%
def string_permute(s):
    out = []

    if len(s) == 1:
        out = [s]

    else:
        for i, let in enumerate(s):

            for letter in string_permute(s[:i] + s[i+1:]):

                out += [let + letter]

    return out

# %%
string_permute('abc')
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']

# %%
string_permute('123')
# Out:
# ['123', '132', '213', '231', '312', '321']

# %%
#Revision
#Date: 20/4/26
#thirdsolve

# %% [markdown]
# ## Problem Statement
#
# Given a string, write a function that uses recursion to output a list of all the possible permutations of that string.
#
# For example, given s='abc' the function should return ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']
#
# *Note: If a character is repeated, treat each occurence as distinct, for example an input of 'xxx' would return a list with 6 "versions" of 'xxx'*

# %%
def permute3(s):
    lst = []

    if len(s) <= 1:
        lst = [s]
        
    else:
        
        for i,v in enumerate(s):
            for let in permute3(s[:i] + s[1+i:]):

                lst += [v + let]
                
    return lst

# %%
permute3('abc')
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']

# %%
permute3('123')
# Out:
# ['123', '132', '213', '231', '312', '321']

# %%
#Revision
#Date: 05/20/26
#forthsolve

# %% [markdown]
# ## Problem Statement
#
# Given a string, write a function that uses recursion to output a list of all the possible permutations of that string.
#
# For example, given s='abc' the function should return ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']
#
# *Note: If a character is repeated, treat each occurence as distinct, for example an input of 'xxx' would return a list with 6 "versions" of 'xxx'*

# %%
def permute4(arr):
    lst = []
    if len(arr) <= 1:
        lst = [arr]
    else:
        for i,j in enumerate(arr):
            for ele in permute4(arr[:i]+arr[i+1:]):
                lst += [j+ele]
    return lst

# %%
permute4('abc')
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']

# %%
#Revision
#Date: 6/9/26
#fifthsolve

# %% [markdown]
# ## Problem Statement
#
# Given a string, write a function that uses recursion to output a list of all the possible permutations of that string.
#
# For example, given s='abc' the function should return ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']
#
# *Note: If a character is repeated, treat each occurence as distinct, for example an input of 'xxx' would return a list with 6 "versions" of 'xxx'*

# %%
def permute5(s):
    output = []
    if len(s) == 1:
        output = [s]
    else:
        for i,j in enumerate(s):
            for ele in permute5(s[:i]+s[1+i:]):

                output += [j + ele]
    return output

# %%
permute5('abc')
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']

# %%
permute5('1234')
# Out:
# ['1234',
#  '1243',
#  '1324',
#  '1342',
#  '1423',
#  '1432',
#  '2134',
#  '2143',
#  '2314',
#  '2341',
#  '2413',
#  '2431',
#  '3124',
#  '3142',
#  '3214',
#  '3241',
#  '3412',
#  '3421',
#  '4123',
#  '4132',
#  '4213',
#  '4231',
#  '4312',
#  '4321']

# %%
permute5('a1')
# Out:
# ['a1', '1a']
