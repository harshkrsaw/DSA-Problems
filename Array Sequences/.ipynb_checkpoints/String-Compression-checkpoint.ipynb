# %% [markdown]
# ## Problem
#
# Given a string in the form 'AAAABBBBCCCCCDDEEEE' compress it to become 'A4B4C5D2E4'. For this problem, you can falsely "compress" strings of single or double letters. For instance, it is okay for 'AAB' to return 'A2B1' even though this technically takes more space.
# |
# The function should also be case sensitive, so that a string 'AAAaaa' returns 'A3a3'.

# %%
def compress(s):
    

    if len(s) == 0:
        return ''
    if len(s) == 1:
        return s + '1'

    count = 1
    r = ""

    for num in range(1,len(s)):
        
        if s[num] == s[num - 1]:
            count += 1
        else:
            r = r + s[num - 1] + str(count)
            count = 1
            
    r = r + s[-1] + str(count)
    
    return r

# %%
compress('AAAABBBBCCCCCDDEEEE')
# Out:
# 'A4B4C5D2E4'

# %%
compress('AAAAAaaaaA')
# Out:
# 'A5a4A1'

# %%
#Revision 
#date: 3/4/26
#secondsolve

# %% [markdown]
# ## Problem
#
# Given a string in the form 'AAAABBBBCCCCCDDEEEE' compress it to become 'A4B4C5D2E4'. For this problem, you can falsely "compress" strings of single or double letters. For instance, it is okay for 'AAB' to return 'A2B1' even though this technically takes more space.
#
# The function should also be case sensitive, so that a string 'AAAaaa' returns 'A3a3'.

# %%
def string_comp(s):
    
    if len(s) == 0:
        return ''
    if len(s) == 1:
        return s + '1'
        
    count = 1
    r = ''
    
    for num in range(1,len(s)):
        if s[num] == s[num - 1]:
            count += 1
        else:
            r = r + s[num-1] + str(count)
            count = 1
    r = r + s[-1] + str(count)
    return r

# %%
string_comp( 'AAAABBBBCCCCCDDEEEEA')
# Out:
# 'A4B4C5D2E4A1'

# %%
string_comp('AAAaaa')
# Out:
# 'A3a3'

# %%
#Revision
#Date: 10/4/26
#Thirdsolve

# %% [markdown]
# ## Problem
#
# Given a string in the form 'AAAABBBBCCCCCDDEEEE' compress it to become 'A4B4C5D2E4'. For this problem, you can falsely "compress" strings of single or double letters. For instance, it is okay for 'AAB' to return 'A2B1' even though this technically takes more space.
# |
# The function should also be case sensitive, so that a string 'AAAaaa' returns 'A3a3'.

# %%
def string_comp(s):

    if len(s) == 0:
        return ''
    
    newstr = ''
    count = 1
    
    for num in range(1,len(s)):

        if s[num] == s[num - 1]:
            count += 1
        else:
            newstr = newstr + s[num - 1] + str(count)
            count = 1

    newstr = newstr + s[-1] + str(count)

    return newstr

# %%
string_comp('AAAABBBBCCCCCDDEEEE')
# Out:
# 'A4B4C5D2E4'

# %%
string_comp('a')
# Out:
# 'a1'

# %%
string_comp('AAAaaa')
# Out:
# 'A3a3'

# %%
string_comp('adhenopoe')
# Out:
# 'a1d1h1e1n1o1p1o1e1'

# %% [markdown]
# ## Problem
#
# Given a string in the form 'AAAABBBBCCCCCDDEEEE' compress it to become 'A4B4C5D2E4'. For this problem, you can falsely "compress" strings of single or double letters. For instance, it is okay for 'AAB' to return 'A2B1' even though this technically takes more space.
# |
# The function should also be case sensitive, so that a string 'AAAaaa' returns 'A3a3'.

# %%
def string_comp(s):

    if len(s) == 0:
        return ''

    count = 1 
    output = ''
    for i in range(1,(len(s))):
        
        if s[i] == s[i-1]:
            count+=1
        else:
            output = output + s[i-1] + str(count)
            count = 1
            
    output = output + s[-1] + str(count)

    return output

# %%
string_comp('b')
# Out:
# 'b1'

# %%
string_comp('AAAABBBBCCCCCDDEEEE')
# Out:
# 'A4B4C5D2E4'

# %%
string_comp('AAAaaa')
# Out:
# 'A3a3'
