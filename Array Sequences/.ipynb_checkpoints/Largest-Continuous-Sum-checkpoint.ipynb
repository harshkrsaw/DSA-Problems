# %% [markdown]
# # Largest Continuous Sum
#
# ## Problem
# Given an array of integers (positive and negative) find the largest continuous sum.
#
# Input:
#     [1,2,-1,3,4,10,10,-10,-1]
#
# Output:
#     29
#
#
# ## Solution
#
# Fill out your solution below:

# %%
def large_cont_sum(arr):
    if len(arr) == 0:
        return 0
    
    current_sum = max_sum = arr[0]
    for num in arr[1::]:
        current_sum = max(num,current_sum + num)
        max_sum = max(current_sum, max_sum)
    return max_sum

# %%
large_cont_sum([1,2,-1,3,4,10,10,-10,-1])
# Out:
# 29

# %%
large_cont_sum([1,2,-1,3,4,-1])
# Out:
# 9

# %%
large_cont_sum([-1,1])
# Out:
# 1

# %%
#Revision
#Date: 28/3/26
#secondsolve

# %% [markdown]
# # Largest Continuous Sum
#
# ## Problem
# Given an array of integers (positive and negative) find the largest continuous sum.
#
# Input:
#     [1,2,-1,3,4,10,10,-10,-1]
#
# Output:
#     29
#
#
# ## Solution
#
# Fill out your solution below:

# %%
def cont_largest_sum(arr):

    if len(arr) == 0:
        return 0
    
    current_sum = total_sum = arr[0]

    for num in arr[1::]:
        current_sum = max(num,num+current_sum)
        total_sum = max(current_sum,total_sum)
    return total_sum

# %%
cont_largest_sum([1,2,-1,3,4,-1])
# Out:
# 9

# %%
cont_largest_sum([-1,1])
# Out:
# 1

# %%
cont_largest_sum([1,2,-1,3,4,10,10,-10,-1])
# Out:
# 29

# %%
#Revision
#Date: 3/4/26
#thirdsolve

# %% [markdown]
# ## Problem
# Given an array of integers (positive and negative) find the largest continuous sum.
#
# Input:
#     [1,2,-1,3,4,10,10,-10,-1]
#
# Output:
#     29

# %%
def LCS(arr):

    if len(arr) == 0:
        return 0

    current_max = total_max = arr[0] 

    for num in arr[1::]:

        current_max = max(num,current_max + num)
        total_max = max(current_max,total_max)

    return total_max

# %%
arr = [1,2,-1,3,4,10,10,-10,-1]
LCS(arr)
# Out:
# 29

# %%
LCS([-1,1])
# Out:
# 1
