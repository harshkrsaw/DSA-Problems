# %% [markdown]
# # Linked List Nth to Last Node
#
# ## Problem Statement
# Write a function that takes a head node and an integer value **n** and then returns the nth to last node in the linked list. For example, given:

# %%
class Node:

    def __init__(self, value):
        self.value = value
        self.nextnode  = None

# %% [markdown]
# **Example Input and Output:**

# %%
a = Node(1)
b = Node(2)
c = Node(3)
d = Node(4)
e = Node(5)

a.nextnode = b
b.nextnode = c
c.nextnode = d
d.nextnode = e

# This would return the node d with a value of 4, because its the 2nd to last node.
#target_node = nth_to_last_node(2, a)

# %%
#target_node

# %% [markdown]
# ## Solution

# %%
def nth_to_last_node(n, head):

    right_pointer = head
    left_pointer = head

    for num in range(n-1):
        
         #For Edge case
         if not right_pointer.nextnode:
            return 'Error: n is larger than the linked list.'

            right_pointer = right_pointer.nextnode
        
    while right_pointer.nextnode:

        right_pointer = right_pointer.nextnode
        left_pointer = left_pointer.nextnode
        
    return left_pointer.value

# %%
nth_to_last_node(2,a)
# Out:
# 4

# %%
nth_to_last_node(4,a)
# Out:
# 2

# %%
#Revision
#Date: 12/4/26
#secondsolve

# %% [markdown]
# # Linked List Nth to Last Node
#
# ## Problem Statement
# Write a function that takes a head node and an integer value **n** and then returns the nth to last node in the linked list. For example, given:

# %%
def nth_to_last_node2(n,head):
    right = head
    left = head

    for num in range(n - 1):
        
        if right.nextnode is None:
            return 'Error: n is larger than the linked list.'
             
        right = right.nextnode

    while right.nextnode:

        right = right.nextnode
        left = left.nextnode

    return left.value

# %%
nth_to_last_node2(1,a)
# Out:
# 5

# %%
nth_to_last_node2(10,a)
# Out:
# 'Error: n is larger than the linked list.'

# %% [markdown]
# ## Problem Statement
# Write a function that takes a head node and an integer value **n** and then returns the nth to last node in the linked list. For example, given:

# %%
class Node:

    def __init__(self, value):
        self.value = value
        self.nextnode  = None

# %%
def last_to_nth_node(head,n):
    fast = head
    slow = head 
    for i in range(n-1):

        fast = fast.nextnode

    while fast.nextnode:

        fast = fast.nextnode
        slow = slow.nextnode
        
    return slow.value

# %%
a = Node(1)
b = Node(2)
c = Node(3)
d = Node(4)
e = Node(5)

a.nextnode = b
b.nextnode = c
c.nextnode = d
d.nextnode = e

# %%
last_to_nth_node(a,4)
# Out:
# 2
